# %%
import torch
from transformers import AutoProcessor, AutoModelForMultimodalLM

MODEL_PATH = "/data/models/Qwen3.5-9B"

processor = AutoProcessor.from_pretrained(
    MODEL_PATH,
    local_files_only=True,
)

model = AutoModelForMultimodalLM.from_pretrained(
    MODEL_PATH,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    local_files_only=True,
)

model.eval()

print("Model je uspešno učitan.")
print("Device:", next(model.parameters()).device)
print(
    "Zauzet VRAM:",
    round(torch.cuda.memory_allocated() / 1024**3, 2),
    "GB",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 from transformers import AutoProcessor, AutoModelForMultimodalLM
#       3
#       4 MODEL_PATH = "/data/models/Qwen3.5-9B"
#       5
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/ccpp_env/lib/python3.11/site-packages/transformers/utils/import_utils.py:2535, in _LazyModule.__getattr__(self, name)
#    2533 elif name in self._class_to_module:
#    2534     try:
# -> 2535         module = self._get_module(self._class_to_module[name])
#    2536         value = getattr(module, name)
#    2537     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2538         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2539         # non-Fast symbol from the same module when available. This lets us keep only one
#    2540         # backend tokenizer class while preserving legacy public names.
#
# File ~/ccpp_env/lib/python3.11/site-packages/transformers/utils/import_utils.py:2769, in _LazyModule._get_module(self, module_name)
#    2767     return importlib.import_module("." + module_name, self.__name__)
#    2768 except Exception as e:
# -> 2769     raise e
#
# File ~/ccpp_env/lib/python3.11/site-packages/transformers/utils/import_utils.py:2767, in _LazyModule._get_module(self, module_name)
#    2765 def _get_module(self, module_name: str):
#    2766     try:
# -> 2767         return importlib.import_module("." + module_name, self.__name__)
#    2768     except Exception as e:
#    2769         raise e
#
# File ~/ccpp_env/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/ccpp_env/lib/python3.11/site-packages/transformers/models/auto/processing_auto.py:25
#      23 from ...dynamic_module_utils import get_class_from_dynamic_module, resolve_trust_remote_code
#      24 from ...feature_extraction_utils import FeatureExtractionMixin
# ---> 25 from ...image_processing_utils import ImageProcessingMixin
#      26 from ...processing_utils import ProcessorMixin
#      27 from ...tokenization_python import TOKENIZER_CONFIG_FILE
#
# File ~/ccpp_env/lib/python3.11/site-packages/transformers/image_processing_utils.py:24
#      21 import numpy as np
#      22 from huggingface_hub.dataclasses import validate_typed_dict
# ---> 24 from .image_processing_base import BatchFeature, ImageProcessingMixin
#      25 from .image_transforms import center_crop, normalize, rescale
#      26 from .image_utils import (
#      27     ChannelDimension,
#      28     ImageInput,
#    (...)     32     validate_preprocess_arguments,
#      33 )
#
# File ~/ccpp_env/lib/python3.11/site-packages/transformers/image_processing_base.py:25
#      23 from .dynamic_module_utils import custom_object_save
#      24 from .feature_extraction_utils import BatchFeature as BaseBatchFeature
# ---> 25 from .image_utils import is_valid_image, load_image
#      26 from .utils import (
#      27     IMAGE_PROCESSOR_NAME,
#      28     PROCESSOR_NAME,
#    (...)     32     safe_load_json_file,
#      33 )
#      34 from .utils.hub import cached_file, hf_api
#
# File ~/ccpp_env/lib/python3.11/site-packages/transformers/image_utils.py:54
#      51     PILImageResampling = PIL.Image.Resampling
#      53 if is_torchvision_available():
# ---> 54     from torchvision.io import ImageReadMode, decode_image
#      55     from torchvision.transforms import InterpolationMode
#      56     from torchvision.transforms.functional import pil_to_tensor
#
# File ~/ccpp_env/lib/python3.11/site-packages/torchvision/__init__.py:8
#       5 # Don't re-order these, we need to load the _C extension (done when importing
#       6 # .extension) before entering _meta_registrations.
#       7 from . import extension  # usort:skip  # noqa: F401
# ----> 8 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      10 try:
#      11     from .version import __version__  # noqa: F401
#
# File ~/ccpp_env/lib/python3.11/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File ~/ccpp_env/lib/python3.11/site-packages/torchvision/models/convnext.py:9
#       6 from torch import nn, Tensor
#       7 from torch.nn import functional as F
# ----> 9 from ..ops.misc import Conv2dNormActivation, Permute
#      10 from ..ops.stochastic_depth import StochasticDepth
#      11 from ..transforms._presets import ImageClassification
#
# File ~/ccpp_env/lib/python3.11/site-packages/torchvision/ops/__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File ~/ccpp_env/lib/python3.11/site-packages/torchvision/ops/poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: list[Tensor]) -> Tensor:
#
# File ~/ccpp_env/lib/python3.11/site-packages/torchvision/ops/roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File ~/ccpp_env/lib/python3.11/site-packages/torch/_dynamo/__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     config,
#      16     convert_frame,
#      17     eval_frame,
#      18     functional_export,
#      19     resume_execution,
#      20 )
#      21 from .backends.registry import list_backends, lookup_backend, register_backend
#      22 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File ~/ccpp_env/lib/python3.11/site-packages/torch/_dynamo/aot_compile.py:17
#      15 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      16 from torch._dynamo.graph_utils import _graph_device_type
# ---> 17 from torch._dynamo.package import SystemInfo
#      19 from . import convert_frame
#      20 from .aot_compile_types import (
#      21     BundledAOTAutogradSerializableCallable,
#      22     SerializableCallable,
#      23 )
#
# File ~/ccpp_env/lib/python3.11/site-packages/torch/_dynamo/package.py:1173
#    1168     from torch._inductor.runtime.cache_dir_utils import cache_dir
#    1170     return cache_dir()
# -> 1173 DynamoCache = DiskDynamoCache(os.path.join(cache_dir(), "dynamo"))
#
# File ~/ccpp_env/lib/python3.11/site-packages/torch/_dynamo/package.py:1170, in cache_dir()
#    1167 def cache_dir() -> str:
#    1168     from torch._inductor.runtime.cache_dir_utils import cache_dir
# -> 1170     return cache_dir()
#
# File ~/ccpp_env/lib/python3.11/site-packages/torch/_inductor/runtime/cache_dir_utils.py:17, in cache_dir()
#      15 cache_dir = os.environ.get("TORCHINDUCTOR_CACHE_DIR")
#      16 if cache_dir is None:
# ---> 17     os.environ["TORCHINDUCTOR_CACHE_DIR"] = cache_dir = default_cache_dir()
#      18 os.makedirs(cache_dir, exist_ok=True)
#      19 return cache_dir
#
# File ~/ccpp_env/lib/python3.11/site-packages/torch/_inductor/runtime/cache_dir_utils.py:23, in default_cache_dir()
#      22 def default_cache_dir() -> str:
# ---> 23     sanitized_username = re.sub(r'[\\/:*?"<>|]', "_", getpass.getuser())
#      24     return os.path.join(
#      25         tempfile.gettempdir() if not is_fbcode() else "/var/tmp",
#      26         "torchinductor_" + sanitized_username,
#      27     )
#
# File ~/ccpp_env/lib/python3.11/getpass.py:169, in getuser()
#     167 # If this fails, the exception will "explain" why
#     168 import pwd
# --> 169 return pwd.getpwuid(os.getuid())[0]
#
# KeyError: 'getpwuid(): uid not found: 1562'
